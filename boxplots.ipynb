# %%
# %matplotlib inline
import pandas as pd

# %%
sub_rates_PD = pd.read_csv('sub_rates_PD.csv', names=['PD_sub_rate'])
sub_rates_PD
# Out:
#       PD_sub_rate
# 0        0.000157
# 1        0.005051
# 2        0.000225
# 3        0.000327
# 4        0.000155
# 5        0.000000
# 6        0.000486
# 7        0.000128
# 8        0.000246
# 9        0.000323
# 10       0.000250
# 11       0.000242
# 12       0.000095
# 13       0.000289
# 14       0.000136
# 15       0.000512
# 16       0.000285
# 17       0.000000
# 18       0.000424
# 19       0.000000
# 20       0.000307
# 21       0.000332
# 22       0.000448
# 23       0.000303
# 24       0.000000
# 25       0.000284
# 26       0.000260
# 27       0.000099
# 28       0.000165
# 29       0.000192
# ...           ...
# 1198     0.000000
# 1199     0.000581
# 1200     0.000250
# 1201     0.000277
# 1202     0.000438
# 1203     0.000567
# 1204     0.000130
# 1205     0.000114
# 1206     0.000122
# 1207     0.000313
# 1208     0.000457
# 1209     0.000000
# 1210     0.000275
# 1211     0.000106
# 1212     0.000136
# 1213     0.000194
# 1214     0.000220
# 1215     0.000234
# ...

# %%
sub_rates_PER = pd.read_csv('sub_rates_PER.csv', names=['PER_sub_rate'])
sub_rates_PER
# Out:
#      PER_sub_rate
# 0        0.000352
# 1        0.000286
# 2        0.000224
# 3        0.000000
# 4        0.000188
# 5        0.000206
# 6        0.000436
# 7        0.000042
# 8        0.000265
# 9        0.000925
# 10       0.000287
# 11       0.000318
# 12       0.000128
# 13       0.000456
# 14       0.000190
# 15       0.000081
# 16       0.000014
# 17       0.000242
# 18       0.000169
# 19       0.000000
# 20       0.000380
# 21       0.000373
# 22       0.000106
# 23       0.000181
# 24       0.000293
# 25       0.000295
# 26       0.000164
# 27       0.000341
# 28       0.000380
# 29       0.000000
# ..            ...
# 255      0.000326
# 256      0.000331
# 257      0.000249
# 258      0.000246
# 259      0.001643
# 260      0.000202
# 261      0.000356
# 262      0.000324
# 263      0.000178
# 264      0.000247
# 265      0.000158
# 266      0.000240
# 267      0.000291
# 268      0.000215
# 269      0.000253
# 270      0.000456
# 271      0.000856
# 272      0.000360
# ...

# %%
sub_rates_TN = pd.read_csv('sub_rates_TN.csv', names=['TN_sub_rate'])
sub_rates_TN
# Out:
#      TN_sub_rate
# 0       0.000305
# 1       0.000417
# 2       0.000163
# 3       0.000517
# 4       0.000259
# 5       0.000604
# 6       0.000308
# 7       0.000210
# 8       0.000415
# 9       0.000203
# 10      0.000300
# 11      0.000163
# 12      0.000182
# 13      0.000486
# 14      0.000089
# 15      0.000419
# 16      0.000498
# 17      0.000227
# 18      0.000294
# 19      0.000507
# 20      0.000388
# 21      0.000473
# 22      0.000289
# 23      0.000319
# 24      0.000187
# 25      0.000404
# 26      0.000157
# 27      0.000170
# 28      0.000374
# 29      0.000188
# ..           ...
# 815     0.000294
# 816     0.000142
# 817     0.000354
# 818     0.000280
# 819     0.000344
# 820     0.000289
# 821     0.000354
# 822     0.000199
# 823     0.000211
# 824     0.000220
# 825     0.000141
# 826     0.000521
# 827     0.000118
# 828     0.000184
# 829     0.000123
# 830     0.000321
# 831     0.000323
# 832     0.000181
# 833     0.000267
# 834     0.000232
# ...

# %%
big_df = pd.concat([sub_rates_TN, sub_rates_PER, sub_rates_PD], axis=1)
big_df
# Out:
#       TN_sub_rate  PER_sub_rate  PD_sub_rate
# 0        0.000305      0.000352     0.000157
# 1        0.000417      0.000286     0.005051
# 2        0.000163      0.000224     0.000225
# 3        0.000517      0.000000     0.000327
# 4        0.000259      0.000188     0.000155
# 5        0.000604      0.000206     0.000000
# 6        0.000308      0.000436     0.000486
# 7        0.000210      0.000042     0.000128
# 8        0.000415      0.000265     0.000246
# 9        0.000203      0.000925     0.000323
# 10       0.000300      0.000287     0.000250
# 11       0.000163      0.000318     0.000242
# 12       0.000182      0.000128     0.000095
# 13       0.000486      0.000456     0.000289
# 14       0.000089      0.000190     0.000136
# 15       0.000419      0.000081     0.000512
# 16       0.000498      0.000014     0.000285
# 17       0.000227      0.000242     0.000000
# 18       0.000294      0.000169     0.000424
# 19       0.000507      0.000000     0.000000
# ...

# %%
big_df.boxplot(column=['TN_sub_rate', 'PER_sub_rate', 'PD_sub_rate'], showfliers=False, grid=False)

# %%
# putting dots in is hard
import numpy as np
sub_rates.boxplot(showfliers=False, grid=False)

for i,d in enumerate(sub_rates):
    y = sub_rates[d]
    x = np.random.normal(i+1, 0.04, len(y))
    plt.plot(x, y, mfc = ["orange","blue","yellow"][i], mec='k', ms=7, marker="o", linestyle="None")

plt.hlines(1,0,4,linestyle="--")
